# %% [markdown]
# <a href="https://colab.research.google.com/github/a6iyyu/PCVK25_3F_23/blob/main/Week1_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **D2. Pengenalan Python untuk membaca dan menampilkan image dengan pengenalan macam-macam Library (Numpy, pandas, cv2, skimage, PIL dan matplotlib).**

# %% [markdown]
# ## **Langkah 1**
#
# Pada tahap persiapan, beberapa _library_ perlu diimpor seperti **numpy**, **polars**, **cv2**, **skimage**, **PIL**, dan **matplotlib**.

# %%
from google.colab.patches import cv2_imshow
from skimage import io, transform
from PIL import Image

import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import polars as pl

# %% [markdown]
# ## **Langkah 2**
#
# Pada langkah ini, kita akan membaca gambar dari URLs, menampilkannya menggunakan OpenCV. Perhatikan ada perbedaan ketika membuka gambar dalam RGB dan BGR. _Channel_ warna _default_ untuk OpenCV adalah BGR.

# %%
# Membuat daftar untuk menyimpan URL dari beberapa gambar.
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://avatars.githubusercontent.com/u/101570458?s=400&u=57163e0401536df6a8e08d2d469823645752a8ba&v=4",
]

# Melakukan perulangan pada tiap URL gambar, beberapa gambar dapat disimpan pada daftar.
for url in urls:
  image = cv.resize(io.imread(url), (0, 0), fx=0.5, fy=0.5) # Membaca gambar sekaligus mengukur ulang gambar menjadi setengahnya.
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)            # Mengonversi warna ke RGB.
  cv2_imshow(cv.hconcat((image, image_2)))                  # Menggabungkan kedua gambar.
  print('\n')                                               # Menampilkan gambar.
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# ## **Langkah 3**
#
# Melihat resolusi gambar.

# %%
height = image_2.shape[0]
width = image_2.shape[1]

print(f"Resolusi gambar adalah {height} x {width}")
cv2_imshow(image_2)
# Out:
# Resolusi gambar adalah 200 x 200
# <PIL.Image.Image image mode=RGB size=200x200>

# %% [markdown]
# ## **Langkah 4**
#
# Mengakses piksel dengan memberi garis diagonal menyilang.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal di tengah gambar.
for y in range(width):
  image_3[int((height) / 2), y] = [255, 255, 255]

cv2_imshow(cv.hconcat((image_2, image_3)))
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# # **Pertanyaan Praktikum D2**
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
#     Jawaban: <u>Karena Google Colab menyediakan lingkungan yang tidak memerlukan instalasi, akses gratis ke sumber daya komputasi canggih seperti GPU/TPU, kemudahan kolaborasi tim, dan penyimpanan berbasis cloud sehingga memungkinkan praktikan fokus pada kode tanpa repot mengurus infrastruktur, serta dapat diakses dari mana saja secara fleksibel.</u>
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua _library_ tersebut harus digunakan dalam praktikum
# sesi ini?
#
#     Jawaban:
#     - Numpy adalah perpustakaan untuk manipulasi _array_, digunakan untuk aljabar linier, transformasi Fourier, dan kemampuan pembangkitan bilangan acak.
#     - Pandas/Polars adalah perpustakaan untuk manipulasi data dan analisis data.
#     - CV2 adalah perpustakaan untuk tugas-tugas pengolahan citra komputer.
#     - Skimage adalah perpustakaan yang mendukung aplikasi pengolahan citra pada Python.
#     - Matplotlib adalah perpustakaan yang menghasilkan grafik dan menyediakan _toolkit_ antarmuka pengguna grafis.
#
#     Sedangkan, _library_ yang harus digunakan dalam praktikum ini hanya CV2 dan Skimage.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut:
#     ```python
#     image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)
#     ```
#     Apa kegunaan kode program tersebut dan apa pengaruhnya jika tidak dilakukan?
#
#     Jawaban: Kode tersebut digunakan untuk mengecilkan gambar menjadi setengah ukuran. Dengan mengecilkan ukuran gambar, proses pengolahan citra selanjutnya akan lebih cepat dan membutuhkan memori yang lebih sedikit karena jumlah piksel yang diproses berkurang.
#
# 4. Perhatikan potongan kode progam berikut:
#     ```python
#     # Membuat garis horizontal di tengah gambar.
#     for y in range(width):
#       image_3[int((height) / 2), y] = [255, 255, 255]
#     ```
#     Apakah kegunaan kode [255, 255, 255]? Jelaskan!
#
#     Jawaban: [255, 255, 255] digunakan untuk memberi warna putih pada piksel tertentu. Misal pada kode tersebut, gambar yang dideklarasikan di _image_3_ akan menampilkan garis lurus tipis di tengah gambar secara horizontal.
#
# 5. Jelaskan keterkaitan antara piksel dan juga resolusi gambar yang tinggi ataupun rendah!
#     Jawaban: Piksel adalah satuan terkecil dari sebuah gambar digital yang merepresentasikan warna pada titik tertentu. Semakin banyak jumlah piksel dalam sebuah gambar, semakin tinggi resolusinya, sehingga detail gambar lebih jelas dan tajam. Sebaliknya, gambar dengan jumlah piksel sedikit memiliki resolusi rendah, membuat detail gambar terlihat buram atau pecah saat diperbesar.

# %% [markdown]
# # **TUGAS PRAKTIKUM D2**
#
# Buat garis vertikal dan garis menyilang diagonal pada gambar keluaran.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal di tengah gambar.
for x in range(height):
  image_3[x, int((width) / 2)] = [255, 255, 255]

cv2_imshow(cv.hconcat((image_2, image_3)))
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis diagonal dari kiri atas ke kanan bawah.
for i in range(min(height, width)):
    image_3[i, i] = [255, 255, 255]

# Membuat garis diagonal dari kanan atas ke kiri bawah.
for i in range(min(height, width)):
    image_3[i, width - 1 - i] = [255, 255, 255]

# Menampilkan gambar.
cv2_imshow(cv.hconcat((image_2, image_3)))
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# Buat garis horizontal berwarna putih di bagian tengah gambar dengan
# panjang tertentu.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal berwarna putih di tengah gambar dengan panjang tertentu.
start = (width // 2) - 50
end = (width // 2) + 5
for y in range(start, end):
    image_3[height // 2, y] = [255, 255, 255]

# Menampilkan gambar.
cv2_imshow(cv.hconcat((image_2, image_3)))
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# Buat kotak menggunakan kumpulan piksel warna putih di sembarang tempat
# dalam gambar.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Tentukan batas kotak
start_x = (width // 2) - 35   # kiri
end_x = (width // 2) + 35     # kanan
start_y = (height // 2) - 35  # atas
end_y = (height // 2) + 35    # bawah

# Membuat persegi dengan warna putih
for y in range(start_y, end_y):
    for x in range(start_x, end_x):
        image_3[y, x] = [255, 255, 255]

# Menampilkan gambar
cv2_imshow(cv.hconcat((image_2, image_3)))
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>
